# %% [markdown]
# <a href="https://colab.research.google.com/github/skillfi/google-colab/blob/notebooks/diffusion_finetune_skyscrapers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Step 1: Download the base model and sample some images from it

# %% [markdown]
# Install all the Huggingface python packages

# %%
# %%capture
# !pip install git+https://github.com/huggingface/diffusers.git
# !pip install accelerate
# !pip install datasets
# !pip install bitsandbytes

# %% [markdown]
# Set an environment variable for the base model to be fine-tuned

# %%
# %env MODEL_NAME=stabilityai/sdxl-turbo

# %% [markdown]
# Define a simple function to plot a list of images returned from the model when generating

# %%
def plot_images(images):
    from matplotlib import pyplot as plt
    plt.figure()
    f, axarr = plt.subplots(1, len(images), figsize=(20,10))
    for ax, img in zip(axarr.flatten(), images):
        ax.imshow(img)
        ax.axis('off')
    plt.show()

# %% [markdown]
# Import the relevant python libraries to load and sample from the Stable Diffusion model

# %%
import os
import torch

from diffusers import StableDiffusionPipeline
from diffusers import DiffusionPipeline
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %% [markdown]
# In this step we initialise the model and move it to the GPU (you need to choose the correct runtime on google colab to run this command). This step will also trigger the download of the model. The model is a few GB, it might take some time but it will be faster than what you expect. 😏

# %%
pipe = StableDiffusionPipeline.from_pretrained(os.getenv('MODEL_NAME'), torch_dtype=torch.float16)
pipe = pipe.to("cuda")

# %% [markdown]
# We set the text prompt for generating the images and run the actual generation.

# %%
prompt = "isometric view of a skyscraper in the style of a city building game"
images = pipe(prompt, num_images_per_prompt=6).images

# %% [markdown]
# Let's plot the images from the base model with our function:

# %%
plot_images(images)

# %% [markdown]
# **IMPORTANT:** We need to free up the memory of the GPU to be able to start the actual training, let's delete the python variables and collect all the garbage using the garbage collector. Finally we use torch to empty the GPU memory

# %%
# Flush the GPU memory to be able to run the training
del pipe
del images

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ## Step 2: Fine-tune the model

# %% [markdown]
# Let's clone the dataset and the hugging face code which contains the finetuning script

# %%
# !git clone https://github.com/huggingface/diffusers.git
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 65872, done.
# remote: Counting objects: 100% (15556/15556), done.
# remote: Compressing objects: 100% (1763/1763), done.
# remote: Total 65872 (delta 14736), reused 13940 (delta 13729), pack-reused 50316
# Receiving objects: 100% (65872/65872), 45.98 MiB | 15.36 MiB/s, done.
# Resolving deltas: 100% (48896/48896), done.

# %% [markdown]
# Set some flags for the finetuning script, the dataset to be used and the number of iterations. Since the dataset we chose is small and we want to finetune quickly using the colab free tier, let's only finetune for 50 epochs

# %%
# %%capture
# %env dataset_name=SkillFi/diffusion-people-1.0
# %env MODEL_NAME=runwayml/stable-diffusion-v1-5
# No need to train the model for long to see meaningful results.
# %env max_training_epochs = 1000

# %% [markdown]
# Now we run the actual fine-tuning script. **IMPORTANT:** Remember if you want to train on google's free T4 GPU it's crucial to add the flag
#
# ```
# --use_8bit_adam
# ```
# We will save the model in the *city-building-model* folder

# %%
from huggingface_hub import login
login('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')
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !pip install peft
# Out:
# Collecting peft
#   Downloading peft-0.11.1-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from peft) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft) (2.3.1+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from peft) (4.42.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft) (4.66.4)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from peft) (0.32.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft) (0.4.3)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from peft) (0.23.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (1.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft) (12.5.82)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Installing collected packages: peft
# Successfully installed peft-0.11.1

# %%
# The --use_8bit_adam flag is crucial to be able to train on the T4 GPU which has only 15GB of memory
# !accelerate launch diffusers/examples/text_to_image/train_text_to_image_lora.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --dataset_name=$dataset_name \
  --mixed_precision="fp16" \
  --resolution=512 --center_crop --random_flip \
  --train_batch_size=1 \
  --use_8bit_adam \
  --gradient_accumulation_steps=4 \
  --max_train_steps=$max_training_epochs \
  --learning_rate=1e-05 \
  --max_grad_norm=1 \
  --lr_scheduler="cosine" --lr_warmup_steps=0 \
  --output_dir="diffusion-people-3.1" \
  --push_to_hub \
  --hub_model_id="SkillFi/diffusion-people-3.1" \
  --report_to=wandb \
  --checkpointing_steps=500 \
  --validation_prompt="Karina" \
  --seed=1336
# Out:
# Streaming output truncated to the last 5000 lines.
# Steps:  16% 16/100 [03:24<18:55, 13.51s/it, lr=9.38e-6, step_loss=0.142]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.22it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.65it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.91it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.57it/s]
# 07/22/2024 17:49:16 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  17% 17/100 [03:38<18:45, 13.56s/it, lr=9.3e-6, step_loss=0.0159] {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.24it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.70it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.92it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.61it/s]
# 07/22/2024 17:49:30 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  18% 18/100 [03:52<18:33, 13.57s/it, lr=9.22e-6, step_loss=0.0132]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.25it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.71it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.88it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.54it/s]
# 07/22/2024 17:49:43 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  19% 19/100 [04:05<18:24, 13.64s/it, lr=9.14e-6, step_loss=0.126] {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.22it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.64it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.56it/s]
# 07/22/2024 17:49:57 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  20% 20/100 [04:19<18:14, 13.68s/it, lr=9.05e-6, step_loss=0.185]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.23it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.69it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.91it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.59it/s]
# 07/22/2024 17:50:11 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  21% 21/100 [04:33<18:00, 13.68s/it, lr=8.95e-6, step_loss=0.00324]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.24it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.70it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.92it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.61it/s]
# 07/22/2024 17:50:25 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  22% 22/100 [04:46<17:47, 13.68s/it, lr=8.85e-6, step_loss=0.0333]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.21it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.63it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.85it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.50it/s]
# 07/22/2024 17:50:38 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  23% 23/100 [05:00<17:35, 13.71s/it, lr=8.75e-6, step_loss=0.0145]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.24it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.69it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.91it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.59it/s]
# 07/22/2024 17:50:52 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  24% 24/100 [05:14<17:17, 13.65s/it, lr=8.64e-6, step_loss=0.136] {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.24it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.70it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.92it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.61it/s]
# 07/22/2024 17:51:06 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  25% 25/100 [05:27<17:01, 13.62s/it, lr=8.64e-6, step_loss=0.00956]07/22/2024 17:51:17 - INFO - accelerate.accelerator - Saving current state to diffusion-people-3.1/checkpoint-25
# 07/22/2024 17:51:23 - INFO - accelerate.checkpointing - Model weights saved in diffusion-people-3.1/checkpoint-25/model.safetensors
# 07/22/2024 17:51:23 - INFO - accelerate.checkpointing - Optimizer state saved in diffusion-people-3.1/checkpoint-25/optimizer.bin
# 07/22/2024 17:51:23 - INFO - accelerate.checkpointing - Scheduler state saved in diffusion-people-3.1/checkpoint-25/scheduler.bin
# 07/22/2024 17:51:23 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in diffusion-people-3.1/checkpoint-25/sampler.bin
# 07/22/2024 17:51:23 - INFO - accelerate.checkpointing - Gradient scaler state saved in diffusion-people-3.1/checkpoint-25/scaler.pt
# 07/22/2024 17:51:23 - INFO - accelerate.checkpointing - Random states saved in diffusion-people-3.1/checkpoint-25/random_states_0.pkl
# Model weights saved in diffusion-people-3.1/checkpoint-25/pytorch_lora_weights.safetensors
# 07/22/2024 17:51:23 - INFO - __main__ - Saved state to diffusion-people-3.1/checkpoint-25
# Steps:  25% 25/100 [05:33<17:01, 13.62s/it, lr=8.54e-6, step_loss=0.554]  {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.49it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:00,  4.50it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:00,  3.42it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  5.41it/s]
# 07/22/2024 17:51:24 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  26% 26/100 [05:46<18:44, 15.20s/it, lr=8.42e-6, step_loss=0.252]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.24it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.71it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.93it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.61it/s]
# 07/22/2024 17:51:38 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  27% 27/100 [06:00<17:56, 14.75s/it, lr=8.31e-6, step_loss=0.00927]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:05,  1.17it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:01<00:01,  3.51it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.81it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.43it/s]
# 07/22/2024 17:51:52 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  28% 28/100 [06:14<17:21, 14.46s/it, lr=8.19e-6, step_loss=0.0123]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.23it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.68it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.57it/s]
# 07/22/2024 17:52:05 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  29% 29/100 [06:27<16:50, 14.23s/it, lr=8.06e-6, step_loss=0.0466]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.22it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.66it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.55it/s]
# 07/22/2024 17:52:19 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  30% 30/100 [06:41<16:26, 14.10s/it, lr=7.94e-6, step_loss=0.024] {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.22it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.66it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.56it/s]
# 07/22/2024 17:52:33 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  31% 31/100 [06:55<16:05, 14.00s/it, lr=7.81e-6, step_loss=0.019] {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.23it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.68it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.88it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.56it/s]
# 07/22/2024 17:52:47 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  32% 32/100 [07:09<15:44, 13.89s/it, lr=7.68e-6, step_loss=0.0448] {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.24it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.69it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.86it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.54it/s]
# 07/22/2024 17:53:00 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  33% 33/100 [07:22<15:27, 13.84s/it, lr=7.55e-6, step_loss=0.124]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.24it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.69it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.91it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.59it/s]
# 07/22/2024 17:53:14 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  34% 34/100 [07:36<15:08, 13.77s/it, lr=7.41e-6, step_loss=0.1]   {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.23it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.67it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.56it/s]
# 07/22/2024 17:53:28 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  35% 35/100 [07:49<14:52, 13.72s/it, lr=7.27e-6, step_loss=0.00387]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.24it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.70it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.57it/s]
# 07/22/2024 17:53:41 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  36% 36/100 [08:03<14:37, 13.71s/it, lr=7.13e-6, step_loss=0.0264] {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:05,  1.14it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:01<00:01,  3.43it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.64it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.20it/s]
# 07/22/2024 17:53:55 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  37% 37/100 [08:17<14:23, 13.71s/it, lr=6.99e-6, step_loss=0.163] {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.23it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.69it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.91it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.58it/s]
# 07/22/2024 17:54:09 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  38% 38/100 [08:30<14:08, 13.68s/it, lr=6.84e-6, step_loss=0.0155]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.22it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.65it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.86it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.52it/s]
# 07/22/2024 17:54:22 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  39% 39/100 [08:44<13:56, 13.72s/it, lr=6.69e-6, step_loss=0.175] {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.22it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.65it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.88it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.55it/s]
# 07/22/2024 17:54:36 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  40% 40/100 [08:58<13:41, 13.70s/it, lr=6.55e-6, step_loss=0.0201]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.23it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.69it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.90it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.58it/s]
# 07/22/2024 17:54:50 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  41% 41/100 [09:12<13:26, 13.67s/it, lr=6.39e-6, step_loss=0.216] {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.24it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.70it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.90it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.57it/s]
# 07/22/2024 17:55:03 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  42% 42/100 [09:25<13:12, 13.66s/it, lr=6.24e-6, step_loss=0.00682]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.24it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.70it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.90it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.59it/s]
# 07/22/2024 17:55:17 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  43% 43/100 [09:39<12:57, 13.63s/it, lr=6.09e-6, step_loss=0.00367]{'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.24it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.71it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.92it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.61it/s]
# 07/22/2024 17:55:31 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  44% 44/100 [09:52<12:42, 13.61s/it, lr=5.94e-6, step_loss=0.0103] {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.24it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.71it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.92it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.62it/s]
# 07/22/2024 17:55:44 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  45% 45/100 [10:06<12:29, 13.63s/it, lr=5.78e-6, step_loss=0.06] {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.23it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# {'shift_factor', 'use_quant_conv', 'force_upcast', 'scaling_factor', 'use_post_quant_conv', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.68it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.57it/s]
# 07/22/2024 17:55:58 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Karina.
# Steps:  46% 46/100 [10:20<12:17, 13.65s/it, lr=5.63e-6, step_loss=0.379] {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:04,  1.23it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# ...
# model.safetensors:  84% 1.45G/1.72G [00:49<00:08, 32.7MB/s]
#
#
#
#
# model.safetensors:  75% 1.30G/1.72G [00:47<00:14, 29.8MB/s]
#
#
# model.safetensors:  73% 1.26G/1.72G [00:45<00:13, 33.3MB/s]
#
#
#
#
# model.safetensors:  76% 1.30G/1.72G [00:47<00:13, 30.4MB/s]
#
# model.safetensors:  80% 1.38G/1.72G [00:48<00:10, 31.6MB/s]
#
# model.safetensors:  81% 1.39G/1.72G [00:48<00:09, 34.7MB/s]
#
#
#
#
# model.safetensors:  76% 1.31G/1.72G [00:47<00:13, 30.7MB/s]
#
#
# model.safetensors:  73% 1.27G/1.72G [00:46<00:17, 26.0MB/s]
#
#
#
#
# model.safetensors:  76% 1.31G/1.72G [00:47<00:13, 30.2MB/s]
# model.safetensors:  85% 1.46G/1.72G [00:49<00:11, 22.8MB/s]
#
#
# model.safetensors:  74% 1.27G/1.72G [00:46<00:12, 36.4MB/s]
# model.safetensors:  85% 1.46G/1.72G [00:49<00:07, 33.2MB/s]
#
# model.safetensors:  81% 1.39G/1.72G [00:48<00:12, 26.9MB/s]
# model.safetensors:  85% 1.47G/1.72G [00:49<00:07, 34.2MB/s]
#
# model.safetensors:  81% 1.40G/1.72G [00:49<00:09, 33.0MB/s]
#
# model.safetensors:  82% 1.41G/1.72G [00:49<00:07, 39.8MB/s]
#
#
# model.safetensors:  74% 1.28G/1.72G [00:46<00:16, 27.3MB/s]
# model.safetensors:  86% 1.47G/1.72G [00:49<00:08, 29.3MB/s]
#
#
# model.safetensors:  75% 1.29G/1.72G [00:46<00:10, 40.0MB/s]
#
#
#
#
# model.safetensors:  76% 1.31G/1.72G [00:48<00:27, 15.0MB/s]
# model.safetensors:  86% 1.48G/1.72G [00:50<00:07, 33.7MB/s]
#
# model.safetensors:  82% 1.41G/1.72G [00:49<00:08, 34.8MB/s]
# model.safetensors:  86% 1.48G/1.72G [00:50<00:06, 35.3MB/s]
#
#
#
#
# model.safetensors:  77% 1.32G/1.72G [00:48<00:19, 20.6MB/s]
#
# model.safetensors:  82% 1.42G/1.72G [00:49<00:09, 30.8MB/s]
#
#
#
#
# model.safetensors:  77% 1.32G/1.72G [00:48<00:15, 25.3MB/s]
#
#
# model.safetensors:  75% 1.30G/1.72G [00:47<00:13, 30.7MB/s]
#
# model.safetensors:  83% 1.42G/1.72G [00:49<00:09, 32.7MB/s]
# model.safetensors:  86% 1.49G/1.72G [00:50<00:09, 25.7MB/s]
#
#
# model.safetensors:  76% 1.30G/1.72G [00:47<00:12, 33.9MB/s]
# model.safetensors:  87% 1.50G/1.72G [00:50<00:06, 32.5MB/s]
#
#
# model.safetensors:  76% 1.31G/1.72G [00:47<00:11, 37.0MB/s]
#
#
#
#
# model.safetensors:  77% 1.33G/1.72G [00:49<00:19, 19.8MB/s]
#
# model.safetensors:  83% 1.43G/1.72G [00:49<00:11, 26.7MB/s]
# model.safetensors:  87% 1.50G/1.72G [00:50<00:05, 37.9MB/s]
#
# model.safetensors:  83% 1.43G/1.72G [00:50<00:10, 28.8MB/s]
#
#
#
#
# model.safetensors:  78% 1.34G/1.72G [00:49<00:15, 25.4MB/s]
#
#
# model.safetensors:  76% 1.31G/1.72G [00:47<00:12, 31.7MB/s]
#
# model.safetensors:  83% 1.43G/1.72G [00:50<00:09, 30.4MB/s]
# model.safetensors:  88% 1.51G/1.72G [00:50<00:06, 30.8MB/s]
#
#
#
#
# model.safetensors:  78% 1.34G/1.72G [00:49<00:13, 28.3MB/s]
#
#
# model.safetensors:  77% 1.32G/1.72G [00:47<00:12, 32.9MB/s]
#
#
# model.safetensors:  77% 1.32G/1.72G [00:47<00:12, 33.2MB/s]
# model.safetensors:  88% 1.51G/1.72G [00:51<00:07, 28.8MB/s]
# model.safetensors:  88% 1.52G/1.72G [00:51<00:05, 38.2MB/s]
#
#
#
#
# model.safetensors:  78% 1.35G/1.72G [00:49<00:19, 19.7MB/s]
#
#
# model.safetensors:  77% 1.33G/1.72G [00:48<00:15, 26.2MB/s]
#
# model.safetensors:  84% 1.44G/1.72G [00:50<00:14, 19.2MB/s]
#
#
#
#
# model.safetensors:  78% 1.35G/1.72G [00:49<00:15, 24.7MB/s]
#
#
# model.safetensors:  78% 1.34G/1.72G [00:48<00:09, 39.8MB/s]
# model.safetensors:  88% 1.52G/1.72G [00:51<00:06, 29.8MB/s]
#
# model.safetensors:  84% 1.45G/1.72G [00:50<00:11, 24.2MB/s]
#
#
# model.safetensors:  78% 1.34G/1.72G [00:48<00:09, 39.5MB/s]
#
#
#
#
# model.safetensors:  79% 1.35G/1.72G [00:50<00:15, 23.5MB/s]
# model.safetensors:  89% 1.53G/1.72G [00:51<00:06, 29.0MB/s]
#
# model.safetensors:  84% 1.45G/1.72G [00:50<00:09, 29.0MB/s]
#
#
#
#
# model.safetensors:  79% 1.36G/1.72G [00:50<00:15, 24.3MB/s]
# model.safetensors:  89% 1.53G/1.72G [00:51<00:06, 31.0MB/s]
#
#
# model.safetensors:  78% 1.35G/1.72G [00:48<00:13, 28.6MB/s]
#
# model.safetensors:  85% 1.46G/1.72G [00:51<00:11, 22.2MB/s]
#
#
# model.safetensors:  79% 1.36G/1.72G [00:48<00:08, 44.1MB/s]
# model.safetensors:  89% 1.54G/1.72G [00:52<00:07, 24.0MB/s]
#
#
#
#
# model.safetensors:  79% 1.36G/1.72G [00:50<00:20, 17.7MB/s]
#
# model.safetensors:  85% 1.47G/1.72G [00:51<00:08, 30.9MB/s]
#
#
#
#
# model.safetensors:  79% 1.37G/1.72G [00:50<00:14, 24.1MB/s]
# model.safetensors:  90% 1.54G/1.72G [00:52<00:06, 29.3MB/s]
#
# model.safetensors:  85% 1.47G/1.72G [00:51<00:07, 33.2MB/s]
#
#
#
#
# model.safetensors:  80% 1.37G/1.72G [00:50<00:12, 27.1MB/s]
# model.safetensors:  90% 1.55G/1.72G [00:52<00:05, 32.5MB/s]
#
#
# model.safetensors:  79% 1.37G/1.72G [00:49<00:12, 28.5MB/s]
#
#
# model.safetensors:  80% 1.38G/1.72G [00:49<00:09, 37.6MB/s]
#
# model.safetensors:  86% 1.47G/1.72G [00:51<00:10, 24.2MB/s]
# model.safetensors:  90% 1.55G/1.72G [00:52<00:07, 23.8MB/s]
#
# model.safetensors:  86% 1.48G/1.72G [00:51<00:06, 37.7MB/s]
#
#
#
#
# model.safetensors:  80% 1.38G/1.72G [00:51<00:18, 18.7MB/s]
# model.safetensors:  91% 1.56G/1.72G [00:52<00:05, 31.9MB/s]
#
#
#
#
# model.safetensors:  80% 1.38G/1.72G [00:51<00:12, 26.6MB/s]
# model.safetensors:  91% 1.57G/1.72G [00:52<00:03, 39.1MB/s]
#
#
# model.safetensors:  80% 1.38G/1.72G [00:49<00:11, 28.5MB/s]
#
# model.safetensors:  87% 1.49G/1.72G [00:52<00:07, 32.2MB/s]
#
#
#
#
# model.safetensors:  81% 1.39G/1.72G [00:51<00:12, 27.6MB/s]
#
#
# model.safetensors:  80% 1.39G/1.72G [00:49<00:11, 29.8MB/s]
#
# model.safetensors:  87% 1.50G/1.72G [00:52<00:07, 32.4MB/s]
#
#
# model.safetensors:  81% 1.39G/1.72G [00:49<00:10, 31.9MB/s]
#
# model.safetensors:  87% 1.50G/1.72G [00:52<00:06, 34.9MB/s]
# model.safetensors:  91% 1.57G/1.72G [00:53<00:05, 25.1MB/s]
#
#
#
#
# model.safetensors:  81% 1.39G/1.72G [00:51<00:14, 22.4MB/s]
# model.safetensors:  92% 1.58G/1.72G [00:53<00:04, 33.7MB/s]
#
# model.safetensors:  87% 1.50G/1.72G [00:52<00:07, 29.3MB/s]
#
#
#
#
# model.safetensors:  81% 1.40G/1.72G [00:51<00:10, 30.7MB/s]
#
#
#
#
# model.safetensors:  82% 1.40G/1.72G [00:51<00:09, 34.9MB/s]
#
# model.safetensors:  88% 1.51G/1.72G [00:52<00:06, 35.0MB/s]
#
# model.safetensors:  88% 1.52G/1.72G [00:52<00:04, 41.5MB/s]
#
#
# model.safetensors:  81% 1.39G/1.72G [00:50<00:18, 17.9MB/s]
#
#
# model.safetensors:  82% 1.41G/1.72G [00:50<00:10, 30.4MB/s]
#
# model.safetensors:  88% 1.52G/1.72G [00:53<00:06, 33.2MB/s]
#
# model.safetensors:  89% 1.53G/1.72G [00:53<00:04, 46.4MB/s]
#
#
#
#
# model.safetensors:  82% 1.41G/1.72G [00:52<00:16, 19.1MB/s]
#
#
# model.safetensors:  82% 1.41G/1.72G [00:50<00:11, 26.9MB/s]
#
#
#
#
# model.safetensors:  82% 1.42G/1.72G [00:52<00:11, 26.2MB/s]
#
#
# model.safetensors:  83% 1.42G/1.72G [00:50<00:07, 38.8MB/s]
#
# model.safetensors:  89% 1.54G/1.72G [00:53<00:05, 31.7MB/s]
#
#
#
#
# model.safetensors:  83% 1.42G/1.72G [00:52<00:11, 26.9MB/s]
#
# model.safetensors:  90% 1.55G/1.72G [00:53<00:04, 40.1MB/s]
#
#
# model.safetensors:  83% 1.43G/1.72G [00:51<00:08, 35.2MB/s]
# model.safetensors:  92% 1.59G/1.72G [00:54<00:10, 13.0MB/s]
#
#
# model.safetensors:  83% 1.44G/1.72G [00:51<00:07, 37.8MB/s]
# model.safetensors:  92% 1.59G/1.72G [00:54<00:09, 14.8MB/s]
#
#
#
#
# model.safetensors:  83% 1.43G/1.72G [00:53<00:14, 21.0MB/s]
# model.safetensors:  93% 1.59G/1.72G [00:54<00:07, 18.1MB/s]
#
#
#
#
# model.safetensors:  83% 1.43G/1.72G [00:53<00:11, 25.6MB/s]
#
# model.safetensors:  90% 1.55G/1.72G [00:54<00:06, 28.2MB/s]
# model.safetensors:  93% 1.60G/1.72G [00:54<00:05, 22.2MB/s]
#
#
#
#
# model.safetensors:  83% 1.44G/1.72G [00:53<00:09, 30.3MB/s]
#
# model.safetensors:  91% 1.56G/1.72G [00:54<00:04, 33.1MB/s]
#
#
# model.safetensors:  84% 1.44G/1.72G [00:51<00:10, 27.5MB/s]
#
# model.safetensors:  91% 1.56G/1.72G [00:54<00:04, 36.1MB/s]
#
#
# model.safetensors:  84% 1.45G/1.72G [00:51<00:08, 32.1MB/s]
# model.safetensors:  93% 1.60G/1.72G [00:55<00:06, 17.7MB/s]
#
#
#
#
# model.safetensors:  84% 1.44G/1.72G [00:53<00:12, 23.0MB/s]
# model.safetensors:  93% 1.61G/1.72G [00:55<00:04, 24.9MB/s]
#
# model.safetensors:  91% 1.57G/1.72G [00:54<00:05, 29.5MB/s]
#
#
#
#
# model.safetensors:  84% 1.45G/1.72G [00:53<00:09, 29.1MB/s]
#
#
# model.safetensors:  85% 1.46G/1.72G [00:52<00:08, 31.4MB/s]
# model.safetensors:  94% 1.61G/1.72G [00:55<00:04, 26.8MB/s]
#
# model.safetensors:  91% 1.58G/1.72G [00:54<00:04, 32.5MB/s]
#
#
#
#
# model.safetensors:  84% 1.45G/1.72G [00:53<00:08, 31.8MB/s]
#
#
# model.safetensors:  85% 1.46G/1.72G [00:52<00:08, 32.7MB/s]
#
# model.safetensors:  92% 1.58G/1.72G [00:54<00:04, 33.1MB/s]
#
#
# model.safetensors:  85% 1.46G/1.72G [00:52<00:07, 32.9MB/s]
# model.safetensors:  94% 1.62G/1.72G [00:55<00:04, 21.9MB/s]
#
#
# model.safetensors:  85% 1.47G/1.72G [00:52<00:06, 39.3MB/s]
#
#
#
#
# model.safetensors:  85% 1.46G/1.72G [00:54<00:11, 24.1MB/s]
# model.safetensors:  94% 1.63G/1.72G [00:55<00:03, 28.8MB/s]
#
# model.safetensors:  92% 1.58G/1.72G [00:55<00:05, 26.4MB/s]
#
#
#
#
# model.safetensors:  85% 1.46G/1.72G [00:54<00:08, 28.9MB/s]
#
#
# model.safetensors:  86% 1.48G/1.72G [00:52<00:07, 32.1MB/s]
# model.safetensors:  95% 1.63G/1.72G [00:55<00:02, 32.8MB/s]
#
# model.safetensors:  92% 1.59G/1.72G [00:55<00:04, 32.1MB/s]
#
#
# model.safetensors:  86% 1.48G/1.72G [00:52<00:07, 32.4MB/s]
#
#
#
#
# model.safetensors:  85% 1.47G/1.72G [00:54<00:07, 32.1MB/s]
#
# model.safetensors:  93% 1.60G/1.72G [00:55<00:03, 32.7MB/s]
#
#
# model.safetensors:  86% 1.48G/1.72G [00:52<00:07, 33.2MB/s]
#
#
# model.safetensors:  86% 1.49G/1.72G [00:52<00:06, 33.8MB/s]
#
#
#
#
# model.safetensors:  86% 1.47G/1.72G [00:54<00:09, 26.9MB/s]
# model.safetensors:  95% 1.63G/1.72G [00:56<00:04, 21.5MB/s]
#
#
#
#
# model.safetensors:  86% 1.48G/1.72G [00:54<00:05, 40.5MB/s]
# model.safetensors:  95% 1.64G/1.72G [00:56<00:03, 26.1MB/s]
#
# model.safetensors:  93% 1.60G/1.72G [00:55<00:05, 22.6MB/s]
# model.safetensors:  96% 1.65G/1.72G [00:56<00:02, 32.9MB/s]
#
# model.safetensors:  93% 1.61G/1.72G [00:55<00:03, 29.9MB/s]
#
#
#
#
# model.safetensors:  86% 1.49G/1.72G [00:55<00:07, 31.3MB/s]
#
#
#
#
# model.safetensors:  87% 1.50G/1.72G [00:55<00:05, 43.4MB/s]
# model.safetensors:  96% 1.65G/1.72G [00:56<00:02, 27.1MB/s]
#
#
# model.safetensors:  87% 1.49G/1.72G [00:53<00:14, 15.8MB/s]
#
# model.safetensors:  94% 1.62G/1.72G [00:56<00:03, 30.0MB/s]
# model.safetensors:  96% 1.66G/1.72G [00:56<00:02, 31.5MB/s]
#
#
# model.safetensors:  87% 1.49G/1.72G [00:53<00:13, 17.4MB/s]
#
#
#
#
# model.safetensors:  87% 1.51G/1.72G [00:55<00:05, 37.7MB/s]
#
# model.safetensors:  94% 1.62G/1.72G [00:56<00:02, 35.4MB/s]
#
#
# model.safetensors:  87% 1.50G/1.72G [00:53<00:10, 21.4MB/s]
# model.safetensors:  97% 1.66G/1.72G [00:57<00:01, 33.3MB/s]
#
#
#
#
# model.safetensors:  88% 1.51G/1.72G [00:55<00:05, 37.4MB/s]
#
# model.safetensors:  95% 1.63G/1.72G [00:56<00:02, 35.2MB/s]
#
#
# model.safetensors:  87% 1.50G/1.72G [00:53<00:09, 23.8MB/s]
#
# model.safetensors:  95% 1.63G/1.72G [00:56<00:02, 35.3MB/s]
#
#
#
#
# model.safetensors:  88% 1.51G/1.72G [00:55<00:06, 34.3MB/s]
# model.safetensors:  97% 1.67G/1.72G [00:57<00:02, 26.5MB/s]
#
# model.safetensors:  95% 1.64G/1.72G [00:56<00:02, 29.9MB/s]
# model.safetensors:  97% 1.67G/1.72G [00:57<00:01, 33.9MB/s]
#
#
# model.safetensors:  87% 1.51G/1.72G [00:54<00:11, 18.3MB/s]
#
#
#
#
# model.safetensors:  88% 1.52G/1.72G [00:55<00:06, 29.3MB/s]
#
# model.safetensors:  95% 1.64G/1.72G [00:56<00:02, 32.3MB/s]
#
#
#
#
# model.safetensors:  89% 1.53G/1.72G [00:56<00:05, 35.5MB/s]
#
#
# model.safetensors:  88% 1.51G/1.72G [00:54<00:09, 23.0MB/s]
#
# model.safetensors:  95% 1.64G/1.72G [00:56<00:02, 32.1MB/s]
#
#
# model.safetensors:  88% 1.52G/1.72G [00:54<00:07, 28.3MB/s]
# model.safetensors:  98% 1.68G/1.72G [00:57<00:01, 26.2MB/s]
#
#
#
#
# model.safetensors:  89% 1.53G/1.72G [00:56<00:05, 33.3MB/s]
# model.safetensors:  98% 1.69G/1.72G [00:57<00:01, 29.9MB/s]
#
#
#
#
# model.safetensors:  89% 1.54G/1.72G [00:56<00:05, 35.3MB/s]
#
# model.safetensors:  96% 1.65G/1.72G [00:57<00:03, 24.1MB/s]
# model.safetensors:  98% 1.69G/1.72G [00:57<00:00, 35.1MB/s]
#
# model.safetensors:  96% 1.65G/1.72G [00:57<00:02, 32.0MB/s]
#
#
# model.safetensors:  88% 1.52G/1.72G [00:54<00:09, 20.8MB/s]
#
#
#
#
# model.safetensors:  89% 1.54G/1.72G [00:56<00:06, 28.9MB/s]
#
# model.safetensors:  96% 1.66G/1.72G [00:57<00:01, 38.0MB/s]
#
#
# model.safetensors:  89% 1.53G/1.72G [00:54<00:07, 25.3MB/s]
#
#
#
#
# model.safetensors:  90% 1.54G/1.72G [00:56<00:06, 27.6MB/s]
# model.safetensors:  98% 1.70G/1.72G [00:58<00:00, 26.8MB/s]
#
#
#
#
# model.safetensors:  90% 1.55G/1.72G [00:56<00:05, 32.9MB/s]
#
#
# model.safetensors:  89% 1.53G/1.72G [00:55<00:06, 30.9MB/s]
# model.safetensors:  99% 1.70G/1.72G [00:58<00:00, 31.1MB/s]
# model.safetensors:  99% 1.71G/1.72G [00:58<00:00, 40.4MB/s]
#
# model.safetensors:  97% 1.67G/1.72G [00:57<00:02, 22.3MB/s]
#
#
# model.safetensors:  89% 1.54G/1.72G [00:55<00:06, 26.5MB/s]
#
#
#
#
# model.safetensors:  90% 1.55G/1.72G [00:57<00:07, 23.9MB/s]
#
# model.safetensors:  97% 1.67G/1.72G [00:57<00:01, 29.7MB/s]
#
#
# model.safetensors:  90% 1.54G/1.72G [00:55<00:05, 31.6MB/s]
#
#
#
#
# model.safetensors:  91% 1.56G/1.72G [00:57<00:05, 29.4MB/s]
#
# model.safetensors:  97% 1.68G/1.72G [00:58<00:01, 31.2MB/s]
#
#
# model.safetensors:  90% 1.55G/1.72G [00:55<00:04, 34.4MB/s]
#
#
#
#
# model.safetensors:  91% 1.56G/1.72G [00:57<00:04, 32.4MB/s]
# model.safetensors: 100% 1.72G/1.72G [00:58<00:00, 26.3MB/s]
# model.safetensors: 100% 1.72G/1.72G [00:58<00:00, 29.6MB/s]
#
# model.safetensors:  98% 1.68G/1.72G [00:58<00:01, 25.4MB/s]
#
#
# model.safetensors:  90% 1.55G/1.72G [00:55<00:06, 25.0MB/s]
#
# model.safetensors:  98% 1.69G/1.72G [00:58<00:00, 36.9MB/s]
#
#
# model.safetensors: 100% 1.72G/1.72G [00:59<00:00, 29.1MB/s]
#
#
#
#
#
# model.safetensors:  91% 1.57G/1.72G [00:57<00:09, 16.7MB/s]
#
# model.safetensors:  99% 1.70G/1.72G [00:58<00:00, 27.1MB/s]
#
#
# model.safetensors:  91% 1.57G/1.72G [00:56<00:05, 27.6MB/s]
#
#
#
# Upload 25 LFS files:   4% 1/25 [00:59<23:49, 59.58s/it]
#
# model.safetensors:  99% 1.70G/1.72G [00:58<00:00, 34.0MB/s]
#
#
#
#
# model.safetensors:  92% 1.58G/1.72G [00:58<00:05, 26.7MB/s]
#
#
# model.safetensors:  91% 1.58G/1.72G [00:56<00:04, 33.6MB/s]
#
#
#
#
# model.safetensors:  92% 1.58G/1.72G [00:58<00:05, 27.6MB/s]
#
# model.safetensors:  99% 1.71G/1.72G [00:59<00:00, 36.7MB/s]
#
#
# model.safetensors:  92% 1.58G/1.72G [00:56<00:03, 36.6MB/s]
#
# model.safetensors: 100% 1.72G/1.72G [00:59<00:00, 30.5MB/s]
#
#
# model.safetensors:  92% 1.59G/1.72G [00:56<00:04, 30.5MB/s]
#
#
#
#
# model.safetensors:  92% 1.59G/1.72G [00:58<00:06, 20.8MB/s]
#
#
# model.safetensors:  93% 1.59G/1.72G [00:56<00:03, 36.5MB/s]
#
#
#
#
# model.safetensors:  92% 1.59G/1.72G [00:58<00:05, 23.3MB/s]
#
#
# model.safetensors:  93% 1.60G/1.72G [00:56<00:02, 41.9MB/s]
#
#
#
#
# model.safetensors: 100% 1.72G/1.72G [00:59<00:00, 28.8MB/s]
#
#
#
#
#
# model.safetensors:  93% 1.60G/1.72G [00:58<00:04, 24.6MB/s]
#
#
#
#
# model.safetensors:  94% 1.61G/1.72G [00:59<00:02, 43.9MB/s]
#
#
#
# Upload 25 LFS files:  28% 7/25 [01:00<01:55,  6.39s/it]
#
#
# model.safetensors:  93% 1.60G/1.72G [00:57<00:05, 20.4MB/s]
#
#
#
#
# model.safetensors:  94% 1.62G/1.72G [00:59<00:03, 31.0MB/s]
#
#
# model.safetensors:  94% 1.62G/1.72G [00:57<00:04, 25.6MB/s]
#
#
# model.safetensors:  95% 1.63G/1.72G [00:57<00:02, 40.3MB/s]
#
#
#
#
# model.safetensors:  95% 1.63G/1.72G [00:59<00:02, 30.6MB/s]
#
#
#
#
# model.safetensors:  96% 1.65G/1.72G [00:59<00:01, 45.5MB/s]
#
#
# model.safetensors:  95% 1.64G/1.72G [00:58<00:02, 32.0MB/s]
#
#
#
#
# model.safetensors:  96% 1.65G/1.72G [01:00<00:01, 41.7MB/s]
#
#
# model.safetensors:  95% 1.64G/1.72G [00:58<00:02, 37.3MB/s]
#
#
#
#
# model.safetensors:  96% 1.66G/1.72G [01:00<00:01, 42.5MB/s]
#
#
# model.safetensors:  96% 1.65G/1.72G [00:58<00:02, 30.4MB/s]
#
#
#
#
# model.safetensors:  97% 1.66G/1.72G [01:00<00:01, 32.2MB/s]
#
#
# model.safetensors:  96% 1.66G/1.72G [00:58<00:01, 35.2MB/s]
#
#
#
#
# model.safetensors:  97% 1.68G/1.72G [01:00<00:01, 45.0MB/s]
#
#
# model.safetensors:  97% 1.66G/1.72G [00:59<00:01, 34.6MB/s]
#
#
#
#
# model.safetensors:  98% 1.68G/1.72G [01:00<00:00, 43.5MB/s]
#
#
#
#
# model.safetensors:  98% 1.69G/1.72G [01:00<00:00, 54.5MB/s]
#
#
# model.safetensors:  97% 1.67G/1.72G [00:59<00:02, 24.6MB/s]
#
#
#
#
# model.safetensors:  99% 1.70G/1.72G [01:01<00:00, 44.9MB/s]
#
#
# model.safetensors:  97% 1.68G/1.72G [00:59<00:01, 34.6MB/s]
#
#
#
#
# model.safetensors:  99% 1.71G/1.72G [01:01<00:00, 46.9MB/s]
#
#
# model.safetensors:  98% 1.68G/1.72G [00:59<00:01, 32.0MB/s]
#
#
# model.safetensors:  98% 1.69G/1.72G [00:59<00:00, 49.2MB/s]
#
#
#
#
# model.safetensors:  99% 1.71G/1.72G [01:01<00:00, 31.3MB/s]
#
#
# model.safetensors: 100% 1.72G/1.72G [01:01<00:00, 27.8MB/s]
#
#
#
# model.safetensors:  99% 1.71G/1.72G [01:00<00:00, 40.0MB/s]
#
#
#
# model.safetensors: 100% 1.72G/1.72G [01:00<00:00, 28.4MB/s]
#
#
#
#
# Upload 25 LFS files: 100% 25/25 [01:04<00:00,  2.57s/it]
# Steps: 100% 100/100 [24:52<00:00, 14.92s/it, lr=0, step_loss=0.321]

# %% [markdown]
# ## Step 3: Sample from the finetuned model

# %% [markdown]
# We load the new model in the GPU (this time we don't need to Download anything as the fine-tuned model has been saved locally) and generate some more images

# %%
pipe = StableDiffusionPipeline.from_pretrained('SkillFi/diffusion-people-3.1', torch_dtype=torch.float16)
pipe = pipe.to("cuda")
prompt = "Karina"
images = pipe(prompt, num_images_per_prompt=6).images
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     303     try:
# --> 304         response.raise_for_status()
#     305     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/SkillFi/diffusion-people-3.1/resolve/main/model_index.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# <ipython-input-29-663162aee063> in <cell line: 1>()
# ----> 1 pipe = StableDiffusionPipeline.from_pretrained('SkillFi/diffusion-people-3.1', torch_dtype=torch.float16)
#       2 pipe = pipe.to("cuda")
#       3 prompt = "Karina"
#       4 images = pipe(prompt, num_images_per_prompt=6).images
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/diffusers/pipelines/pipeline_utils.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     697                     " is neither a valid local path nor a valid repo id. Please check the parameter."
#     698                 )
# --> 699             cached_folder = cls.download(
#     700                 pretrained_model_name_or_path,
#     701                 cache_dir=cache_dir,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/diffusers/pipelines/pipeline_utils.py in download(cls, pretrained_model_name, **kwargs)
#    1296
#    1297         if not local_files_only:
# -> 1298             config_file = hf_hub_download(
#    1299                 pretrained_model_name,
#    1300                 cls.config_name,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, legacy_cache_layout, resume_download, force_filename, local_dir_use_symlinks)
#    1219         )
#    1220     else:
# -> 1221         return _hf_hub_download_to_cache_dir(
#    1222             # Destination
#    1223             cache_dir=cache_dir,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, headers, proxies, etag_timeout, endpoint, local_files_only, force_download)
#    1280     # Try to get metadata (etag, commit_hash, url, size) from the server.
#    1281     # If we can't, a HEAD request error is returned.
# -> 1282     (url_to_download, etag, commit_hash, expected_size, head_call_error) = _get_metadata_or_catch_error(
#    1283         repo_id=repo_id,
#    1284         filename=filename,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, local_files_only, relative_filename, storage_folder)
#    1720         try:
#    1721             try:
# -> 1722                 metadata = get_hf_file_metadata(url=url, proxies=proxies, timeout=etag_timeout, headers=headers)
#    1723             except EntryNotFoundError as http_error:
#    1724                 if storage_folder is not None and relative_filename is not None:
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers)
#    1643
#    1644     # Retrieve metadata
# -> 1645     r = _request_wrapper(
#    1646         method="HEAD",
#    1647         url=url,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     370     # Recursively follow relative redirects
#     371     if follow_relative_redirects:
# --> 372         response = _request_wrapper(
#     373             method=method,
#     374             url=url,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     394     # Perform request and return if status_code is not in the retry list.
#     395     response = get_session().request(method=method, url=url, **params)
# --> 396     hf_raise_for_status(response)
#     397     return response
#     398
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     313         elif error_code == "EntryNotFound":
#     314             message = f"{response.status_code} Client Error." + "\n\n" + f"Entry Not Found for url: {response.url}."
# --> 315             raise EntryNotFoundError(message, response) from e
#     316
#     317         elif error_code == "GatedRepo":
#
# EntryNotFoundError: 404 Client Error. (Request ID: Root=1-669e4c71-1c2a459a3726a11e28e88004;46075f84-09c4-42ac-9147-25cfe51e7725)
#
# Entry Not Found for url: https://huggingface.co/SkillFi/diffusion-people-3.1/resolve/main/model_index.json.

# %% [markdown]
# The new images! Hopefully the quality improved thanks to the finetuning process. You can play with the number of epochs to see how the fine-tuning process impacts the final output 💪

# %%
plot_images(images)
